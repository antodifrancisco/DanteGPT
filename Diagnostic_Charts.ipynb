# %% [markdown]
# ### Diagnostic charts
#
# In this notebook we recap and analyze the charts that have been used by Karpathy to learn the behavior of neural networks.

# %% [markdown]
# #### Distribution of letters with embedding

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8,8))
plt.scatter(C[:,0].data, C[:,1].data, s=200)
plt.grid("minor")
for i in range(C.shape[0]):
    plt.text(C[i,0].item(), C[i,1].item(), itos[i], ha="center", va="center", color='white')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 print(loss.item())
#       4 plt.figure(figsize=(8,8))
#       5 plt.scatter(C[:,0].data, C[:,1].data, s=200)
#
# NameError: name 'loss' is not defined

# %% [markdown]
# #### Basic tanh plat

# %%
plt.hist(h.view(-1).tolist(), 50);
plt.hist(hpreact.view(-1).tolist(), 50);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.hist(h.view(-1).tolist(), 50);
#       2 plt.hist(hpreact.view(-1).tolist(), 50);
#
# NameError: name 'plt' is not defined

# %% [markdown]
# #### Saturation in a grid of black and whites

# %%
plt.figure(figsize=(20, 10))
plt.imshow(h.abs() > 0.99, cmap="gray", interpolation="none");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.figure(figsize=(20, 10))
#       2 plt.imshow(h.abs() > 0.99, cmap="gray", interpolation="none");
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create random data
data1 = np.random.rand(50)
data2 = np.random.rand(50)
itos = ["a"] * 50

# Create a scatter plot
plt.figure(figsize=(6, 6))
plt.scatter(data1, data2, s=200, c='blue', alpha=0.5)
plt.xlabel('Data 1')
plt.ylabel('Data 2')
plt.title('Scatter Plot')
# for i in range(len(data1)):
#     plt.text(data1[i].item(), data2[i].item(), itos[i], ha="center", va="center", color='white')
# plt.show()
# Out:
# Text(0.5, 1.0, 'Scatter Plot')
